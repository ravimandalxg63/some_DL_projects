# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from  sklearn.preprocessing import OneHotEncoder,StandardScaler

# %%
irik=load_iris()

# %%
x=irik['data']
y=irik['target']
#print(x)

# %%
# scale the x so they are betwwn 0,1
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,)
model=tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(activation='relu',input_dim=4,units=4,kernel_initializer='uniform'))
model.add(tf.keras.layers.Dense(activation='relu',units=4,kernel_initializer='uniform'))
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(tf.keras.layers.Dense(1,activation='sigmoid',kernel_initializer='uniform'))

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])
model.fit(x_train,y_train,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6750 - loss: 0.3328
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6750 - loss: 0.3327
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3326
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3325
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3324
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3323
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3323
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3322
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3321
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6750 - loss: 0.3320
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6750 - loss: 0.3320
# Epoch 12/100
# ...

# %%
x_train.shape
# Out:
# (120, 4)

# %%
# pedicting values from test sets
y_pred=model.predict(x_test)
model.evaluate(x_test,y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6333 - loss: 0.3703
# [0.370326429605484, 0.6333333253860474]

# %%
# plots 
fig,ax=plt.subplots()
ax.scatter(y_test,y_pred)
ax.plot([y_train.min(),y_test.max()],[y_test.min(),y_test.max()])
ax.set_label('calculate')
ax.set_ylabel('prediction')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       3 ax.scatter(y_test,y_pred)
#       4 ax.plot([y_train.min(),y_test.max()],[y_test.min(),y_test.max()])
# ----> 5 ax.x_label('calculate')
#       6 ax.y_label('prediction')
#       7 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'x_label'

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Read image
img = cv2.imread(
    r'C:\Users\PC\OneDrive\Documents\ravi.jpeg',
    cv2.IMREAD_GRAYSCALE
)

# Check whether image was loaded
if img is None:
    print("ERROR: Image not found. Check the file path.")
else:
    # Resize to 28x28
    image_res = cv2.resize(img, (28, 28))

    # Add batch dimension
    input_imz = np.expand_dims(image_res, axis=0)

    print("Image shape:", image_res.shape)
    print("Input shape:", input_imz.shape)

    # Display image
    plt.imshow(image_res, cmap='gray')
    plt.axis('off')
    plt.show()
